# %% [markdown]
# # Topic modeling for EHRI testimonies
#
# Michal Frankl
#
# This notebook performs basic topic modeling on testimonies published in the [EHRI Edition of Early Holocaust Testimony](https://early-testimony.ehri-project.eu/). It is meant as only a first, indicative step, or a proof-of-concept for a potential wider study of Holocaust testimonies.
#
# Most of the code below was adapted from the Jupyter notebook by Mike Bryant and Maria Dermentzi [Exploratory Topic Modelling Using Python](https://github.com/EHRI/ehri-data-analysis-tools/blob/master/topic-modelling-python/USHMM_Oral_Testimonies_Topic_Modelling.ipynb), without much further fine-tuning and exploration. Please see there for further explanations and considerations. At its current stage, this script only uses the English versions of the testimonies, many of them translations.

# %% [markdown]
# ## Install and necessary Python modules

# %%
# !pip install pandas
# !pip install tei-reader
# !pip install gensim
# !pip install pyLDAvis
# !pip install requests
# !pip install spacy
# !pip install nltk
# !pip install pyarrow
# Out:
# Requirement already satisfied: pandas in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: tei-reader in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (0.0.17)
# Requirement already satisfied: beautifulsoup4 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from tei-reader) (4.12.3)
# Requirement already satisfied: lxml in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from tei-reader) (5.1.0)
# Requirement already satisfied: soupsieve>1.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from beautifulsoup4->tei-reader) (2.5)
# Requirement already satisfied: gensim in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from gensim) (1.12.0)
# Requirement already satisfied: smart-open>=1.8.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from gensim) (6.4.0)
# Requirement already satisfied: pyLDAvis in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pyLDAvis) (1.26.4)
# Requirement already satisfied: scipy in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pyLDAvis) (1.12.0)
# Requirement already satisfied: pandas>=2.0.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pyLDAvis) (2.2.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pyLDAvis) (1.3.2)
# Requirement already satisfied: jinja2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pyLDAvis) (3.1.3)
# Requirement already satisfied: numexpr in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pyLDAvis) (2.9.0)
# Requirement already satisfied: funcy in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pyLDAvis) (1.4.1.post1)
# Requirement already satisfied: gensim in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pyLDAvis) (4.3.2)
# Requirement already satisfied: setuptools in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pyLDAvis) (69.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.3.0)
# Requirement already satisfied: smart-open>=1.8.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from gensim->pyLDAvis) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from jinja2->pyLDAvis) (2.1.5)
# Requirement already satisfied: six>=1.5 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: requests in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from requests) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from requests) (2024.2.2)
# Requirement already satisfied: spacy in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (2.6.1)
# Requirement already satisfied: jinja2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (69.0.3)
# Requirement already satisfied: packaging>=20.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: nltk in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (3.8.1)
# Requirement already satisfied: click in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from nltk) (4.66.2)
# Requirement already satisfied: pyarrow in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (15.0.0)
# Requirement already satisfied: numpy<2,>=1.16.6 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pyarrow) (1.26.4)

# %%
import os
from tei_reader import TeiReader
import pandas as pd
import re
import requests
import numpy as np
import spacy
# !python3 -m spacy download en_core_web_sm
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from warnings import filterwarnings
filterwarnings('ignore')
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 37.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.1)
# Requirement already satisfied: jinja2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.0.3)
# Requirement already satisfied: packaging>=20.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/michal/bin/miniconda3/envs/topic-modeling/lib/python3.9/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [nltk_data] Downloading package stopwords to /home/michal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Lemmatisation and corpus cleaning
#
# Copied from Dermentzi/Bryant; for some languages, spaCy would have to be replaced by another solution (likely nltk).

# %%
# Loading the English pipeline and model 
nlp = spacy.load("en_core_web_sm", exclude=["ner", "parser"])
nlp.max_length=3000000

"""
Defining the lemmatisation function:
Each document fed into the function, we parse it using the spacy pipeline; 
tokenise it; check whether each of its tokens is a noun and is not included in the stopword list or 
is not a punctuation and consists of only alphabetic characters. If a token passes
these checks, then we take its lemma and append it to the list of lemmas
that the function will output.
"""

# This function is inspired by Mattingly's (2021, 2022) tutorials on topic modelling

def lemmatise(text, allowed_postags=["NOUN"]):
    text_out = ""
    doc = nlp(text, disable=['ner','parser'])
    new_text = []
    for token in doc:
        if token.pos_ in allowed_postags and token.lower_ not in stopwords and not token.is_punct and token.is_alpha:
            new_text.append(token.lemma_)
    text_out = new_text
    return (text_out)

# %%
stopwords = stopwords.words("english")

# %%
testimony_dir = "early-testimony_ENG"

directory = os.fsencode(testimony_dir)

testimonies = []

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".xml"): 
        file = testimony_dir + '/' + filename
#        print(file)
        reader = TeiReader()
        corpora = reader.read_file(file)
        text = corpora.text.replace("\n", " ")
#        print(corpora.text)
        ltext = lemmatise(text)
        testimonies.append({
            "filename": filename,
            "edition": filename.split('-')[1],
            "ltext": ltext
        })

# %% [markdown]
# _For now, we use the tei_reader module to extract text from the TEI source files. Potentially, a more robust solution, or perhaps preprocesseing of the TEI files might be applied._

# %%
# testimonies

# %% [markdown]
# ## Load into a Pandas dataframe

# %%
testimoniesdf = pd.DataFrame.from_dict(testimonies)

# %%
testimoniesdf.head()
# Out:
#                     filename edition  \
# 0   EHRI-ET-DEGOB0701_EN.xml      ET
# 1  EHRI-ET-ZIH3010025_EN.xml      ET
# 2   EHRI-ET-DEGOB0748_EN.xml      ET
# 3  EHRI-ET-WL05320171_EN.xml      ET
# 4  EHRI-ET-ZIH3010317_EN.xml      ET
#
#                                                ltext
# 0  [day, country, pack, husband, service, comrade...
# 1  [née, voivodeship, education, year, school, pa...
# 2  [father, brother, part, day, parent, week, bor...
# 3  [city, city, delegate, detachment, day, decree...
# 4  [daughter, mother, née, education, school, fam...

# %% [markdown]
# ## Build the vector for topic modeling

# %%
dictionary = Dictionary(documents=testimoniesdf['ltext'].to_list(), prune_at=None)
dictionary.filter_extremes(no_above=0.6, keep_n=None)  # Filter out words that appear too often
dictionary.compactify() # Assign new ids to words

# %%
temp = dictionary[0]  # This is only to "load" the dictionary
dictionary.id2token
# Out:
# {0: 'People',
#  1: 'aid',
#  2: 'arrival',
#  3: 'beginning',
#  4: 'block',
#  5: 'body',
#  6: 'building',
#  7: 'call',
#  8: 'car',
#  9: 'chamber',
#  10: 'chimney',
#  11: 'clothe',
#  12: 'cold',
#  13: 'commando',
#  14: 'comrade',
#  15: 'country',
#  16: 'death',
#  17: 'doctor',
#  18: 'document',
#  19: 'effect',
#  20: 'end',
#  21: 'enemy',
#  22: 'evening',
#  23: 'fire',
#  24: 'freight',
#  25: 'gas',
#  26: 'head',
#  27: 'hell',
#  28: 'home',
#  29: 'hospital',
#  30: 'husband',
#  31: 'information',
#  32: 'kitchen',
#  33: 'leg',
#  34: 'life',
#  35: 'line',
#  36: 'luggage',
#  37: 'mattress',
#  38: 'memory',
#  39: 'mill',
#  40: 'month',
#  41: 'neighbourhood',
#  42: 'noon',
#  43: 'open',
#  44: 'other',
#  45: 'part',
#  46: 'person',
#  47: 'photo',
#  48: 'pit',
#  49: 'plant',
#  50: 'pocket',
#  51: 'policeman',
#  52: 'prisoner',
#  53: 'provision',
#  54: 'punishment',
#  55: 'quarantine',
#  56: 'question',
#  57: 'rail',
#  58: 'railway',
#  59: 'rain',
#  60: 'reason',
#  61: 'report',
#  62: 'road',
#  63: 'roll',
#  64: 'room',
#  65: 'selection',
#  66: 'service',
#  67: 'shoe',
#  68: 'station',
#  69: 'straw',
#  70: 'train',
#  71: 'transport',
#  72: 'travel',
#  73: 'treatment',
#  74: 'trench',
#  75: 'typhus',
#  76: 'workplace',
#  77: 'area',
#  78: 'arm',
#  79: 'army',
#  80: 'attack',
#  81: 'attic',
#  82: 'authority',
#  83: 'band',
#  84: 'barn',
#  85: 'belly',
#  86: 'bottle',
#  87: 'brick',
#  88: 'brother',
#  89: 'bullet',
#  90: 'bundle',
#  91: 'card',
#  92: 'cart',
#  93: 'cemetery',
#  94: 'chairman',
#  95: 'clothing',
#  96: 'commander',
#  97: 'contribution',
#  98: 'couple',
#  99: 'dawn',
#  100: 'direction',
#  101: 'distance',
#  102: 'education',
#  103: 'elder',
#  104: 'existence',
#  105: 'eye',
#  106: 'father',
#  107: 'fence',
#  108: 'field',
#  109: 'fight',
#  110: 'flame',
#  111: 'foot',
#  112: 'forest',
#  113: 'form',
#  114: 'front',
#  115: 'fur',
#  116: 'garden',
#  117: 'ghetto',
#  118: 'girl',
#  119: 'gold',
#  120: 'good',
#  121: 'grenade',
#  122: 'group',
#  123: 'gun',
#  124: 'half',
#  125: 'hand',
#  126: 'horse',
#  127: 'hour',
#  128: 'house',
#  129: 'instruction',
#  130: 'killing',
#  131: 'kilometer',
#  132: 'look',
#  133: 'lot',
#  134: 'machine',
#  135: 'market',
#  136: 'master',
#  137: 'midday',
#  138: 'militia',
#  139: 'moment',
#  140: 'money',
#  141: 'morning',
#  142: 'mother',
#  143: 'name',
#  144: 'neck',
#  145: 'neighbouring',
#  146: 'note',
#  147: 'number',
#  148: 'née',
#  149: 'occupation',
#  150: 'order',
#  151: 'owner',
#  152: 'parent',
#  153: 'partisan',
#  154: 'path',
#  155: 'peasant',
#  156: 'permission',
#  157: 'petrol',
#  158: 'pig',
#  159: 'police',
#  160: 'potato',
#  161: 'rest',
#  162: 'return',
#  163: 'right',
#  164: 'ruin',
#  165: 'school',
#  166: 'second',
#  167: 'shooting',
#  168: 'shop',
#  169: 'shot',
#  170: 'sister',
#  171: 'situation',
#  172: 'smoke',
#  173: 'sound',
#  174: 'square',
#  175: 'stage',
#  176: 'street',
#  177: 'tailor',
#  178: 'tax',
#  179: 'territory',
#  180: 'town',
#  181: 'trade',
#  182: 'unit',
#  183: 'vice',
#  184: 'village',
#  185: 'window',
#  186: 'wood',
#  187: 'worker',
#  188: 'blanket',
#  189: 'blow',
#  190: 'border',
#  191: 'boy',
#  192: 'bread',
#  193: 'centre',
#  194: 'company',
#  195: 'door',
#  196: 'firm',
#  197: 'foreman',
#  198: 'gendarme',
#  199: 'grass',
#  200: 'hunger',
#  201: 'iron',
#  202: 'job',
#  203: 'journey',
#  204: 'kilometre',
#  205: 'labour',
#  206: 'leader',
#  207: 'litre',
#  208: 'march',
#  209: 'plan',
#  210: 'portion',
#  211: 'profession',
#  212: 'quarter',
#  213: 'raid',
#  214: 'sanatorium',
#  215: 'soup',
#  216: 'space',
#  217: 'starvation',
#  218: 'suicide',
#  219: 'supply',
#  220: 'tree',
#  221: 'acquaintance',
#  222: 'advance',
#  223: 'apartment',
#  224: 'baggage',
#  225: 'basement',
#  226: 'boat',
#  227: 'cash',
#  228: 'check',
#  229: 'city',
#  230: 'clerk',
#  231: 'condition',
#  232: 'courtyard',
#  233: 'cousin',
#  234: 'daughter',
#  235: 'decree',
#  236: 'detachment',
#  237: 'fruit',
#  238: 'glass',
#  239: 'hat',
#  240: 'hundred',
#  241: 'individual',
#  242: 'key',
#  243: 'kind',
#  244: 'lady',
#  245: 'land',
#  246: 'merchandise',
#  247: 'orphan',
#  248: 'patrol',
#  249: 'possession',
#  250: 'refugee',
#  251: 'resident',
#  252: 'river',
#  253: 'rope',
#  254: 'route',
#  255: 'search',
#  256: 'soldier',
#  257: 'store',
#  258: 'suffering',
#  259: 'sum',
#  260: 'synagogue',
#  261: 'turn',
#  262: 'whip',
#  263: 'wife',
#  264: 'back',
#  265: 'bed',
#  266: 'blood',
#  267: 'book',
#  268: 'business',
#  269: 'cinema',
#  270: 'circle',
#  271: 'community',
#  272: 'corner',
#  273: 'crowd',
#  274: 'difference',
#  275: 'employee',
#  276: 'entry',
#  277: 'estate',
#  278: 'execution',
#  279: 'guard',
#  280: 'jewelry',
#  281: 'lawyer',
#  282: 'letter',
#  283: 'mayor',
#  284: 'mean',
#  285: 'meeting',
#  286: 'mercy',
#  287: 'midnight',
#  288: 'office',
#  289: 'plane',
#  290: 'poster',
#  291: 'prison',
#  292: 'revenge',
#  293: 'ring',
#  294: 'sick',
#  295: 'side',
#  296: 'silver',
#  297: 'ss',
#  298: 'star',
#  299: 'tram',
#  300: 'truck',
#  301: 'valuable',
#  302: 'wall',
#  303: 'war',
#  304: 'wedding',
#  305: 'account',
#  306: 'adult',
#  307: 'affair',
#  308: 'appearance',
#  309: 'armband',
#  310: 'attempt',
#  311: 'barrier',
#  312: 'battle',
#  313: 'belonging',
#  314: 'bit',
#  315: 'bombing',
#  316: 'bunk',
#  317: 'cattle',
#  318: 'chance',
#  319: 'coffee',
#  320: 'consciousness',
#  321: 'conversation',
#  322: 'dark',
#  323: 'departure',
#  324: 'deportation',
#  325: 'deportee',
#  326: 'distribution',
#  327: 'dozen',
#  328: 'driver',
#  329: 'duty',
#  330: 'east',
#  331: 'escape',
#  332: 'exchange',
#  333: 'exhaustion',
#  334: 'factory',
#  335: 'fate',
#  336: 'gentleman',
#  337: 'gram',
#  338: 'hope',
#  339: 'hut',
#  340: 'idea',
#  341: 'impression',
#  342: 'inspection',
#  343: 'inspector',
#  344: 'kilo',
#  345: 'km',
#  346: 'language',
#  347: 'law',
#  348: 'light',
#  349: 'loaf',
#  350: 'luck',
#  351: 'metre',
#  352: 'mine',
#  353: 'nature',
#  354: 'noise',
#  355: 'observation',
#  356: 'officer',
#  357: 'opinion',
#  358: 'parcel',
#  359: 'pile',
#  360: 'plenty',
#  361: 'presence',
#  362: 'ration',
#  363: 'reality',
#  364: 'region',
#  365: 'round',
#  366: 'sack',
#  367: 'site',
#  368: 'state',
#  369: 'story',
#  370: 'supervisor',
#  371: 'team',
#  372: 'thing',
#  373: 'thought',
#  374: 'thousand',
#  375: 'tin',
#  376: 'uniform',
#  377: 'wagon',
#  378: 'watch',
#  379: 'yard',
#  380: 'difficulty',
#  381: 'scene',
#  382: 'air',
#  383: 'break',
#  384: 'coal',
#  385: 'concert',
#  386: 'courage',
#  387: 'dance',
#  388: 'drop',
#  389: 'extermination',
#  390: 'floor',
#  391: 'german',
#  392: 'instrument',
#  393: 'lack',
#  394: 'middle',
#  395: 'piece',
#  396: 'plate',
#  397: 'point',
#  398: 'queue',
#  399: 'radio',
#  400: 'stuff',
#  401: 'system',
#  402: 'toilet',
#  403: 'trace',
#  404: 'water',
#  405: 'action',
#  406: 'addition',
#  407: 'barrack',
#  408: 'barracks',
#  409: 'bath',
#  410: 'capo',
#  411: 'cellar',
#  412: 'charge',
#  413: 'column',
#  414: 'commandant',
#  415: 'corpse',
#  416: 'deputy',
#  417: 'ditch',
#  418: 'entrance',
#  419: 'evidence',
#  420: 'fact',
#  421: 'fellow',
#  422: 'fighting',
#  423: 'gasoline',
#  424: 'hair',
#  425: 'headquarter',
#  426: 'heap',
#  427: 'hole',
#  428: 'lieutenant',
#  429: 'living',
#  430: 'meter',
#  431: 'minute',
#  432: 'nerve',
#  433: 'none',
#  434: 'poison',
#  435: 'position',
#  436: 'post',
#  437: 'preparation',
#  438: 'revolver',
#  439: 'rubble',
#  440: 'secretary',
#  441: 'sign',
#  442: 'spot',
#  443: 'staff',
#  444: 'stretcher',
#  445: 'suspicion',
#  446: 'task',
#  447: 'telephone',
#  448: 'testimony',
#  449: 'tool',
#  450: 'tooth',
#  451: 'towel',
#  452: 'warehouse',
#  453: 'weapon',
#  454: 'wire',
#  455: 'address',
#  456: 'despair',
#  457: 'event',
#  458: 'film',
#  459: 'folk',
#  460: 'force',
#  461: 'future',
#  462: 'hall',
#  463: 'heart',
#  464: 'hit',
#  465: 'inmate',
#  466: 'labor',
#  467: 'material',
#  468: 'news',
#  469: 'pain',
#  470: 'past',
#  471: 'prayer',
#  472: 'resistance',
#  473: 'singing',
#  474: 'song',
#  475: 'strength',
#  476: 'success',
#  477: 'tear',
#  478: 'term',
#  479: 'tragedy',
#  480: 'word',
#  481: 'afternoon',
#  482: 'age',
#  483: 'application',
#  484: 'author',
#  485: 'brutality',
#  486: 'cigarette',
#  487: 'colleague',
#  488: 'control',
#  489: 'corridor',
#  490: 'course',
#  491: 'date',
#  492: 'deal',
#  493: 'department',
#  494: 'employment',
#  495: 'fear',
#  496: 'friend',
#  497: 'index',
#  498: 'list',
#  499: 'lorry',
#  500: 'loss',
#  501: 'marriage',
#  502: 'member',
#  503: 'message',
#  504: 'occasion',
#  505: 'official',
#  506: 'outbreak',
#  507: 'paper',
#  508: 'party',
#  509: 'period',
#  510: 'persecution',
#  511: 'present',
#  512: 'regard',
#  513: 'regulation',
#  514: 'relative',
#  515: 'representative',
#  516: 'request',
#  517: 'signature',
#  518: 'spite',
#  519: 'table',
#  520: 'terror',
#  521: 'title',
#  522: 'touch',
#  523: 'uncle',
#  524: 'church',
#  525: 'circumstance',
#  526: 'eve',
#  527: 'highway',
#  528: 'massacre',
#  529: 'merchant',
#  530: 'pm',
#  531: 'population',
#  532: 'shoemaker',
#  533: 'son',
#  534: 'threat',
#  535: 'act',
#  536: 'agreement',
#  537: 'ammunition',
#  538: 'atmosphere',
#  539: 'aunt',
#  540: 'basis',
#  541: 'case',
#  542: 'certificate',
#  543: 'class',
#  544: 'concentration',
#  545: 'contact',
#  546: 'content',
#  547: 'disease',
#  548: 'effort',
#  549: 'emigration',
#  550: 'exit',
#  551: 'experience',
#  552: 'friendship',
#  553: 'holiday',
#  554: 'interest',
#  555: 'manager',
#  556: 'manner',
#  557: 'mountain',
#  558: 'nationality',
#  559: 'need',
#  560: 'opportunity',
#  561: 'page',
#  562: 'passport',
#  563: 'peace',
#  564: 'permit',
#  565: 'possibility',
#  566: 'protection',
#  567: 'purpose',
#  568: 'regime',
#  569: 'relation',
#  570: 'religion',
#  571: 'role',
#  572: 'sense',
#  573: 'separation',
#  574: 'ship',
#  575: 'source',
#  576: 'sport',
#  577: 'ticket',
#  578: 'today',
#  579: 'view',
#  580: 'winter',
#  581: 'youth',
#  582: 'activity',
#  583: 'animal',
#  584: 'archive',
#  585: 'arrest',
#  586: 'attention',
#  587: 'bag',
#  588: 'behalf',
#  589: 'box',
#  590: 'bunker',
#  591: 'campaign',
#  592: 'carriage',
#  593: 'cause',
#  594: 'chair',
#  595: 'civilian',
#  596: 'command',
#  597: 'connection',
#  598: 'court',
#  599: 'crematorium',
#  600: 'crime',
#  601: 'danger',
#  602: 'degree',
#  603: 'destination',
#  604: 'discussion',
#  605: 'dress',
#  606: 'evacuation',
#  607: 'example',
#  608: 'experiment',
#  609: 'face',
#  610: 'feeling',
#  611: 'figure',
#  612: 'file',
#  613: 'flour',
#  614: 'freedom',
#  615: 'gate',
#  616: 'harassment',
#  617: 'heat',
#  618: 'help',
#  619: 'illness',
#  620: 'infection',
#  621: 'inhabitant',
#  622: 'inscription',
#  623: 'interrogation',
#  624: 'jail',
#  625: 'leadership',
#  626: 'linen',
#  627: 'mass',
#  628: 'notice',
#  629: 'performance',
#  630: 'pistol',
#  631: 'registration',
#  632: 'result',
#  633: 'rifle',
#  634: 'row',
#  635: 'sentence',
#  636: 'sight',
#  637: 'sort',
#  638: 'spring',
#  639: 'step',
#  640: 'summer',
#  641: 'supervision',
#  642: 'tent',
#  643: 'torment',
#  644: 'uprising',
#  645: 'victim',
#  646: 'whole',
#  647: 'wish',
#  648: 'world',
#  649: 'amount',
#  650: 'announcement',
#  651: 'arrangement',
#  652: 'assistance',
#  653: 'breakfast',
#  654: 'care',
#  655: 'caretaker',
#  656: 'change',
#  657: 'committee',
#  658: 'consulate',
#  659: 'crown',
#  660: 'demand',
#  661: 'destruction',
#  662: 'detail',
#  663: 'director',
#  664: 'disposal',
#  665: 'district',
#  666: 'epidemic',
#  667: 'farewell',
#  668: 'fever',
#  669: 'funeral',
#  670: 'furniture',
#  671: 'goodbye',
#  672: 'hardship',
#  673: 'health',
#  674: 'history',
#  675: 'hold',
#  676: 'infant',
#  677: 'institution',
#  678: 'intention',
#  679: 'intervention',
#  680: 'joy',
#  681: 'level',
#  682: 'library',
#  683: 'liquidation',
#  684: 'love',
#  685: 'meal',
#  686: 'meantime',
#  687: 'military',
#  688: 'misery',
#  689: 'mood',
#  690: 'necessity',
#  691: 'negotiation',
#  692: 'neighbour',
#  693: 'operation',
#  694: 'orphanage',
#  695: 'outside',
#  696: 'park',
#  697: 'pass',
#  698: 'payment',
#  699: 'physician',
#  700: 'residence',
#  701: 'risk',
#  702: 'roof',
#  703: 'rule',
#  704: 'rumor',
#  705: 'soul',
#  706: 'status',
#  707: 'support',
#  708: 'teacher',
#  709: 'third',
#  710: 'trouble',
#  711: 'vicinity',
#  712: 'visit',
#  713: 'warden',
#  714: 'worry',
#  715: 'barber',
#  716: 'citizen',
#  717: 'hiding',
#  718: 'hotel',
#  719: 'method',
#  720: 'neighborhood',
#  721: 'thank',
#  722: 'agony',
#  723: 'atrocity',
#  724: 'bomb',
#  725: 'ceiling',
#  726: 'cook',
#  727: 'injury',
#  728: 'shelter',
#  729: 'spirit',
#  730: 'statement',
#  731: 'surgeon',
#  732: 'torture',
#  733: 'witness',
#  734: 'workshop',
#  735: 'wound',
#  736: 'accordance',
#  737: 'cap',
#  738: 'grocery',
#  739: 'ice',
#  740: 'leather',
#  741: 'majority',
#  742: 'mob',
#  743: 'textile',
#  744: 'boss',
#  745: 'organisation',
#  746: 'price',
#  747: 'product',
#  748: 'squad',
#  749: 'survivor',
#  750: 'talk',
#  751: 'zloty',
#  752: 'appeal',
#  753: 'aryan',
#  754: 'autumn',
#  755: 'axis',
#  756: 'beating',
#  757: 'bowl',
#  758: 'complaint',
#  759: 'cost',
#  760: 'craftsman',
#  761: 'crisis',
#  762: 'damage',
#  763: 'examination',
#  764: 'exception',
#  765: 'flesh',
#  766: 'game',
#  767: 'greeting',
#  768: 'item',
#  769: 'jacket',
#  770: 'lunch',
#  771: 'mark',
#  772: 'matter',
#  773: 'power',
#  774: 'property',
#  775: 'release',
#  776: 'shirt',
#  777: 'sibling',
#  778: 'sock',
#  779: 'start',
#  780: 'stay',
#  781: 'stone',
#  782: 'tea',
#  783: 'trouser',
#  784: 'underwear',
#  785: 'value',
#  786: 'washing',
#  787: 'weather',
#  788: 'beast',
#  789: 'ground',
#  790: 'left',
#  791: 'skin',
#  792: 'troop',
#  793: 'answer',
#  794: 'behaviour',
#  795: 'bug',
#  796: 'chain',
#  797: 'character',
#  798: 'coat',
#  799: 'collection',
#  800: 'copy',
#  801: 'cry',
#  802: 'engineer',
#  803: 'following',
#  804: 'generation',
#  805: 'grave',
#  806: 'newspaper',
#  807: 'object',
#  808: 'orchard',
#  809: 'organization',
#  810: 'photocopy',
#  811: 'professor',
#  812: 'remark',
#  813: 'section',
#  814: 'sergeant',
#  815: 'stranger',
#  816: 'student',
#  817: 'total',
#  818: 'trip',
#  819: 'volunteer',
#  820: 'artillery',
#  821: 'axe',
#  822: 'bakery',
#  823: 'bandit',
#  824: 'bayonet',
#  825: 'beard',
#  826: 'bridge',
#  827: 'fun',
#  828: 'knife',
#  829: 'lice',
#  830: 'masse',
#  831: 'neighbor',
#  832: 'neighboring',
#  833: 'pane',
#  834: 'panic',
#  835: 'photograph',
#  836: 'priest',
#  837: 'rabbi',
#  838: 'robbery',
#  839: 'scream',
#  840: 'shtetl',
#  841: 'shtetlekh',
#  842: 'speech',
#  843: 'advantage',
#  844: 'board',
#  845: 'butter',
#  846: 'laundry',
#  847: 'liter',
#  848: 'margarine',
#  849: 'marmalade',
#  850: 'meat',
#  851: 'occurrence',
#  852: 'offence',
#  853: 'package',
#  854: 'record',
#  855: 'sausage',
#  856: 'shift',
#  857: 'shower',
#  858: 'snow',
#  859: 'stable',
#  860: 'bone',
#  861: 'cell',
#  862: 'contrast',
#  863: 'ear',
#  864: 'earth',
#  865: 'excitement',
#  866: 'flat',
#  867: 'government',
#  868: 'imprisonment',
#  869: 'incident',
#  870: 'influence',
#  871: 'labourer',
#  872: 'liberation',
#  873: 'management',
#  874: 'measure',
#  875: 'mind',
#  876: 'mouth',
#  877: 'music',
#  878: 'newcomer',
#  879: 'patient',
#  880: 'picture',
#  881: 'practice',
#  882: 'problem',
#  883: 'relief',
#  884: 'self',
#  885: 'stock',
#  886: 'suburb',
#  887: 'suitcase',
#  888: 'trial',
#  889: 'being',
#  890: 'birth',
#  891: 'boot',
#  892: 'bucket',
#  893: 'criminal',
#  894: 'decision',
#  895: 'knowledge',
#  896: 'pace',
#  897: 'process',
#  898: 'sand',
#  899: 'spoon',
#  900: 'surprise',
#  901: 'vegetable',
#  902: 'attitude',
#  903: 'consequence',
#  904: 'favour',
#  905: 'pair',
#  906: 'race',
#  907: 'stick',
#  908: 'working',
#  909: 'accommodation',
#  910: 'annihilation',
#  911: 'assistant',
#  912: 'clock',
#  913: 'diamond',
#  914: 'documentation',
#  915: 'farmer',
#  916: 'frost',
#  917: 'jewellery',
#  918: 'kg',
#  919: 'murder',
#  920: 'nurse',
#  921: 'security',
#  922: 'wailing',
#  923: 'commission',
#  924: 'farm',
#  925: 'phone',
#  926: 'creature',
#  927: 'dog',
#  928: 'misfortune',
#  929: 'pleasure',
#  930: 'reply',
#  931: 'series',
#  932: 'sleep',
#  933: 'theatre',
#  934: 'tomorrow',
#  935: 'truth',
#  936: 'administration',
#  937: 'bank',
#  938: 'gathering',
#  939: 'horror',
#  940: 'household',
#  941: 'pity',
#  942: 'pressure',
#  943: 'procedure',
#  944: 'shock',
#  945: 'soap',
#  946: 'struggle',
#  947: 'taxi',
#  948: 'vehicle',
#  949: 'wave',
#  950: 'exercise',
#  951: 'baby',
#  952: 'darkness',
#  953: 'medicine',
#  954: 'movement',
#  955: 'responsibility',
#  956: 'slice',
#  957: 'training',
#  958: 'up',
#  959: 'aktion',
#  960: 'crop',
#  961: 'fashion',
#  962: 'council',
#  963: 'dirt',
#  964: 'drink',
#  965: 'instance',
#  966: 'invasion',
#  967: 'knee',
#  968: 'lamp',
#  969: 'length',
#  970: 'murderer',
#  971: 'puddle',
#  972: 'relationship',
#  973: 'soil',
#  974: 'hay',
#  975: 'height',
#  976: 'leave',
#  977: 'commotion',
#  978: 'dinner',
#  979: 'milk',
#  980: 'skeleton',
#  981: 'smell',
#  982: 'target',
#  983: 'top',
#  984: 'overseer',
#  985: 'pretext',
#  986: 'rank',
#  987: 'cannon',
#  988: 'passenger',
#  989: 'pot',
#  990: 'rag',
#  991: 'construction',
#  992: 'munition',
#  993: 'tradesman',
#  994: 'airplane',
#  995: 'stair',
#  996: 'miracle',
#  997: 'pole',
#  998: 'sky',
#  999: 'sun',
#  ...}

# %%
corpus = [dictionary.doc2bow(doc) for doc in testimoniesdf['ltext'].to_list()]  # convert list of tokens to bag of word representation

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 1036
# Number of documents: 125

# %% [markdown]
# ## Train the model
#
# For now, I have opted for six topics and otherwise haven't thinkered with the paramenters of the model. To be done later on.

# %%
# Set training parameters. (Řehůřek, 2022b)
num_topics = 6 # The number of topics
passes =20 # The number of times the algorithm will go through the entire corpus
iterations = 400
chunksize = 50
eval_every = None
random_state = 0 # This is used to make this process reproducible

# Make an index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

model_6_topics = LdaModel(
    corpus=corpus,
    id2word=id2word,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    chunksize=chunksize,
    eval_every = eval_every,
    random_state=random_state
)

# %%
model_6_topics.print_topics(num_words=30)
# Out:
# [(0,
#   '0.078*"city" + 0.059*"shtetl" + 0.032*"street" + 0.021*"store" + 0.018*"population" + 0.018*"house" + 0.017*"fire" + 0.016*"community" + 0.016*"order" + 0.015*"synagogue" + 0.015*"refugee" + 0.014*"victim" + 0.012*"bomb" + 0.011*"foot" + 0.011*"morning" + 0.011*"route" + 0.011*"basement" + 0.010*"crowd" + 0.010*"train" + 0.010*"money" + 0.009*"apartment" + 0.009*"home" + 0.009*"commander" + 0.008*"individual" + 0.008*"decree" + 0.008*"building" + 0.007*"merchandise" + 0.007*"group" + 0.007*"resident" + 0.007*"part"'),
#  (1,
#   '0.032*"car" + 0.025*"border" + 0.023*"bread" + 0.022*"factory" + 0.021*"money" + 0.020*"train" + 0.019*"water" + 0.016*"thing" + 0.015*"worker" + 0.014*"brother" + 0.014*"month" + 0.014*"wagon" + 0.013*"clothe" + 0.012*"hour" + 0.012*"journey" + 0.011*"station" + 0.011*"boy" + 0.010*"piece" + 0.010*"lot" + 0.010*"potato" + 0.010*"evening" + 0.010*"pit" + 0.010*"sister" + 0.010*"soup" + 0.010*"morning" + 0.010*"foot" + 0.009*"guard" + 0.009*"village" + 0.008*"barrack" + 0.008*"bunker"'),
#  (2,
#   '0.043*"house" + 0.034*"village" + 0.028*"farmer" + 0.024*"partisan" + 0.019*"fire" + 0.019*"forest" + 0.017*"corpse" + 0.016*"airplane" + 0.016*"police" + 0.015*"town" + 0.014*"mother" + 0.014*"synagogue" + 0.014*"priest" + 0.013*"girl" + 0.012*"bridge" + 0.012*"bomb" + 0.011*"kilometer" + 0.010*"street" + 0.010*"morning" + 0.009*"name" + 0.009*"road" + 0.009*"belonging" + 0.008*"wagon" + 0.008*"courtyard" + 0.008*"yard" + 0.008*"direction" + 0.008*"home" + 0.008*"horse" + 0.008*"market" + 0.008*"cart"'),
#  (3,
#   '0.016*"transport" + 0.015*"prisoner" + 0.010*"order" + 0.010*"home" + 0.009*"number" + 0.008*"office" + 0.008*"ghetto" + 0.007*"house" + 0.007*"case" + 0.007*"war" + 0.007*"hour" + 0.007*"death" + 0.007*"barrack" + 0.007*"life" + 0.007*"month" + 0.006*"group" + 0.006*"mother" + 0.006*"thing" + 0.006*"course" + 0.006*"block" + 0.006*"doctor" + 0.006*"member" + 0.006*"other" + 0.005*"call" + 0.005*"gas" + 0.005*"concentration" + 0.005*"morning" + 0.005*"part" + 0.005*"end" + 0.005*"guard"'),
#  (4,
#   '0.001*"plant" + 0.001*"selection" + 0.001*"rule" + 0.001*"risk" + 0.001*"status" + 0.001*"physician" + 0.001*"teacher" + 0.001*"third" + 0.001*"trouble" + 0.001*"vicinity" + 0.001*"soul" + 0.001*"support" + 0.001*"pass" + 0.001*"library" + 0.001*"park" + 0.001*"outside" + 0.001*"orphanage" + 0.001*"operation" + 0.001*"neighbour" + 0.001*"negotiation" + 0.001*"necessity" + 0.001*"mood" + 0.001*"misery" + 0.001*"military" + 0.001*"meantime" + 0.001*"meal" + 0.001*"love" + 0.001*"payment" + 0.001*"residence" + 0.001*"roof"'),
#  (5,
#   '0.032*"ghetto" + 0.023*"daughter" + 0.020*"husband" + 0.017*"son" + 0.016*"room" + 0.015*"apartment" + 0.013*"door" + 0.013*"house" + 0.012*"father" + 0.011*"mother" + 0.011*"parent" + 0.011*"hand" + 0.010*"brother" + 0.010*"wife" + 0.009*"friend" + 0.009*"city" + 0.009*"hiding" + 0.009*"street" + 0.009*"group" + 0.008*"end" + 0.008*"money" + 0.008*"officer" + 0.008*"action" + 0.008*"thing" + 0.008*"water" + 0.007*"factory" + 0.007*"eye" + 0.007*"soldier" + 0.007*"grave" + 0.007*"bank"')]

# %%
top_topics = model_6_topics.top_topics(corpus)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)
# Out:
# Average topic coherence: -1.5243.
# [([(0.016075734, 'transport'),
#    (0.015271248, 'prisoner'),
#    (0.010251147, 'order'),
#    (0.009739055, 'home'),
#    (0.008732267, 'number'),
#    (0.00795466, 'office'),
#    (0.007712003, 'ghetto'),
#    (0.0072530783, 'house'),
#    (0.0070971674, 'case'),
#    (0.0070124683, 'war'),
#    (0.0068565123, 'hour'),
#    (0.006783877, 'death'),
#    (0.0066802246, 'barrack'),
#    (0.0065473905, 'life'),
#    (0.0065277517, 'month'),
#    (0.006146308, 'group'),
#    (0.0061378665, 'mother'),
#    (0.0059158076, 'thing'),
#    (0.0058753435, 'course'),
#    (0.005796325, 'block')],
#   -0.72891670623474),
#  ([(0.031666033, 'ghetto'),
#    (0.02281146, 'daughter'),
#    (0.020376636, 'husband'),
#    (0.016730422, 'son'),
#    (0.015529929, 'room'),
#    (0.014975363, 'apartment'),
#    (0.012832854, 'door'),
#    (0.012555443, 'house'),
#    (0.011523316, 'father'),
#    (0.011039054, 'mother'),
#    (0.010834783, 'parent'),
#    (0.010650832, 'hand'),
#    (0.010192903, 'brother'),
#    (0.009804148, 'wife'),
#    (0.0093086865, 'friend'),
#    (0.00923052, 'city'),
#    (0.009188031, 'hiding'),
#    (0.009151534, 'street'),
#    (0.008847958, 'group'),
#    (0.008473424, 'end')],
#   -0.7938958854378881),
#  ([(0.031598594, 'car'),
#    (0.025368495, 'border'),
#    (0.022723585, 'bread'),
#    (0.021809159, 'factory'),
#    (0.020699851, 'money'),
#    (0.020486105, 'train'),
#    (0.019129222, 'water'),
#    (0.01558879, 'thing'),
#    (0.015255391, 'worker'),
#    (0.014422307, 'brother'),
#    (0.013979324, 'month'),
#    (0.013960615, 'wagon'),
#    (0.012501701, 'clothe'),
#    (0.012247071, 'hour'),
#    (0.0119850235, 'journey'),
#    (0.0107049, 'station'),
#    (0.010549907, 'boy'),
#    (0.010430512, 'piece'),
#    (0.010217559, 'lot'),
#    (0.010100731, 'potato')],
#   -0.8321416346502735),
#  ([(0.07830536, 'city'),
#    (0.059388265, 'shtetl'),
#    (0.032117758, 'street'),
#    (0.021059945, 'store'),
#    (0.018357556, 'population'),
#    (0.01831609, 'house'),
#    (0.016790949, 'fire'),
#    (0.015744863, 'community'),
#    (0.015718322, 'order'),
#    (0.015333368, 'synagogue'),
#    (0.015012136, 'refugee'),
#    (0.014356855, 'victim'),
#    (0.012202763, 'bomb'),
#    (0.011448392, 'foot'),
#    (0.010996616, 'morning'),
#    (0.010757978, 'route'),
#    (0.010749025, 'basement'),
#    (0.0100537455, 'crowd'),
#    (0.00968087, 'train'),
#    (0.009546518, 'money')],
#   -1.1906690542061498),
#  ([(0.042966142, 'house'),
#    (0.034182128, 'village'),
#    (0.027814649, 'farmer'),
#    (0.023720633, 'partisan'),
#    (0.01923887, 'fire'),
#    (0.018607158, 'forest'),
#    (0.017301926, 'corpse'),
#    (0.015842972, 'airplane'),
#    (0.015836963, 'police'),
#    (0.014800183, 'town'),
#    (0.014330208, 'mother'),
#    (0.014305261, 'synagogue'),
#    (0.013525391, 'priest'),
#    (0.0126081025, 'girl'),
#    (0.012307845, 'bridge'),
#    (0.0122915665, 'bomb'),
#    (0.011115004, 'kilometer'),
#    (0.010348726, 'street'),
#    (0.009779452, 'morning'),
#    (0.009237705, 'name')],
#   -1.9614248536736811),
#  ([(0.0009652511, 'plant'),
#    (0.0009652511, 'selection'),
#    (0.00096525106, 'pass'),
#    (0.00096525106, 'library'),
#    (0.00096525106, 'park'),
#    (0.00096525106, 'outside'),
#    (0.00096525106, 'orphanage'),
#    (0.00096525106, 'operation'),
#    (0.00096525106, 'neighbour'),
#    (0.00096525106, 'negotiation'),
#    (0.00096525106, 'necessity'),
#    (0.00096525106, 'mood'),
#    (0.00096525106, 'misery'),
#    (0.00096525106, 'military'),
#    (0.00096525106, 'meantime'),
#    (0.00096525106, 'meal'),
#    (0.00096525106, 'love'),
#    (0.00096525106, 'payment'),
#    (0.00096525106, 'third'),
#    (0.00096525106, 'vicinity')],
#   -3.638614154603106)]

# %% [markdown]
# ## Visualise the six topics using pyLDAvis

# %%
# pyLDAvis.enable_notebook()
vis = gensimvis.prepare(model_6_topics, corpus, dictionary, sort_topics=False)
pyLDAvis.save_html(vis, 'model_6_topics.html')
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el5442781397536336501603748899287" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el5442781397536336501603748899287_data = {"mdsDat": {"x": [-0.20321926205815571, 0.22367976494695282, -0.11461229769366188, 0.03234097856714851, 0.012532308315032123, 0.049278507922684525], "y": [-0.15158947961829092, -0.15680691247445402, 0.04627793856267161, 0.061152816883385135, 0.06281946625083251, 0.13814617039585597], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [6.614618146687387, 12.774596636016474, 8.54482229127182, 54.823018010971914, 0.002097707781491335, 17.240847207270914]}, "tinfo": {"Term": ["city", "house", "shtetl", "street", "car", "village", "ghetto", "prisoner", "border", "daughter", "transport", "husband", "bread", "factory", "train", "order", "worker", "farmer", "fire", "money", "home", "office", "water", "town", "population", "partisan", "apartment", "mother", "month", "thing", "route", "merchandise", "massacre", "tear", "shtetlekh", "merchant", "gymnasium", "beard", "mill", "fun", "shtetl", "grocery", "crowd", "pane", "rabbi", "eve", "robbery", "city", "store", "gasoline", "cash", "individual", "decree", "military", "neighboring", "writer", "masse", "community", "basement", "song", "victim", "population", "resident", "synagogue", "bomb", "street", "refugee", "fire", "territory", "foot", "house", "order", "commander", "morning", "apartment", "train", "money", "home", "building", "group", "part", "bone", "misfortune", "construction", "plant", "hay", "grass", "pit", "singing", "ward", "hotel", "platform", "cinema", "photo", "sanatorium", "leave", "rain", "tree", "barber", "instrument", "gram", "height", "bunker", "orphan", "iron", "layer", "baggage", "tomorrow", "freight", "border", "fence", "potato", "car", "bread", "today", "whip", "journey", "soup", "factory", "water", "wagon", "train", "money", "worker", "boy", "kilometre", "brother", "clothe", "piece", "station", "lot", "thing", "month", "line", "foot", "sister", "ground", "hour", "evening", "guard", "morning", "village", "barrack", "farmer", "airplane", "partisan", "ruin", "movement", "training", "product", "bridge", "militia", "priest", "barn", "mob", "kilometer", "contribution", "dawn", "belonging", "revolver", "market", "vicinity", "village", "boat", "corner", "bundle", "corpse", "forest", "beast", "prayer", "cart", "rumor", "patrol", "courtyard", "yard", "bomb", "fire", "synagogue", "direction", "house", "horse", "police", "road", "town", "girl", "mother", "square", "peasant", "name", "street", "morning", "wagon", "refugee", "home", "prisoner", "office", "block", "gas", "call", "roll", "selection", "crematorium", "passport", "country", "transport", "cell", "example", "government", "position", "department", "contact", "summer", "emigration", "section", "ration", "course", "task", "concentration", "detail", "fever", "winter", "treatment", "process", "behalf", "doctor", "chamber", "member", "case", "number", "service", "condition", "home", "reason", "order", "war", "barrack", "other", "life", "death", "part", "month", "hour", "group", "ghetto", "mother", "house", "thing", "guard", "morning", "end", "tin", "crop", "wailing", "trip", "neighbourhood", "notary", "hit", "vice", "observation", "occurrence", "heap", "third", "tool", "skeleton", "target", "pane", "penalty", "regard", "baggage", "grocery", "lamp", "rail", "source", "inspector", "trouser", "layer", "clock", "chair", "past", "site", "plant", "selection", "People", "aid", "arrival", "beginning", "block", "body", "building", "call", "car", "chamber", "chimney", "clothe", "cold", "commando", "comrade", "country", "death", "doctor", "document", "effect", "end", "enemy", "evening", "fire", "freight", "gas", "head", "hell", "bank", "armband", "husband", "identity", "newspaper", "testimony", "dozen", "conversation", "aunt", "daughter", "aktion", "leather", "neighborhood", "fashion", "bombing", "pogrom", "drink", "game", "inspection", "hiding", "soil", "hut", "gathering", "fur", "estate", "medicine", "farm", "bullet", "responsibility", "stranger", "coat", "good", "po ...

# %% [markdown]
# ## Conclusion
#
# This script is only a first step towards a broader exploration of (early and other) Holocaust testimonies using topic modeling. The results, without any fine-tuning, seem encouraging and the extracted topics relatively coherent and significant. Further analysis is needed.
